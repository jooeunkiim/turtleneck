# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
n = pd.read_csv('data/normal.csv')
r = pd.read_csv('data/Right1000.csv')
df_list = [n, r]

# %%
for df in df_list:
    df['y position'] = (df['leftTop y'] + df['rightBottom y']) / 2

# %%
n.head()
# Out:
#    TIME  leftTop x  leftTop y  rightBottom x  rightBottom y   area  areaRatio  \
# 0     0        232        122            391            318  31164   1.000000
# 1     1        235        128            398            325  32111   1.030388
# 2     2        237        128            399            326  32076   1.029265
# 3     3        233        127            397            326  32636   1.047234
# 4     4        233        127            398            327  33000   1.058914
#
#    y position
# 0       220.0
# 1       226.5
# 2       227.0
# 3       226.5
# 4       227.0

# %%
plt.figure(figsize=(15, 5))
plt.title("Face area ratio")
plt.plot(r1['areaRatio'])
plt.plot(n['areaRatio'])

# %%
plt.figure(figsize=(15, 5))
plt.title("y position of face")
plt.plot(r1['y position'])
plt.plot(n['y position'])
